# %% [markdown]
# ## Lab 8, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
tf.compat.v1.enable_eager_execution()

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 200285
# Vectorization...
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Training (reduce the number of epochs, it takes a lot of time!!)
# -  Each epoch takes 5-10 minutes or so on a CPU (an epoch took 7.5 minutes for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (2-3 hours)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=4,
          callbacks=[print_callback])
# Out:
# Train on 200285 samples
# Epoch 1/4
#  - ETA: 1s - loss: 1.9631
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which is a man and propers of the hist the more and the spirit and the self the species and the species of the superse of the which the self-experient and provers of the discive and supers and the morality the spirits and propere the some still that it is a reare experience and a propere and the prospres and the prover of the stall and the self-experient and the self of the readous and in the concept
# ----- diversity: 0.5
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which is a mivele are a mare and intention and the propent in there the mrans and in the discaring and the free the concession of the belief and a mast, and as a reading in this the conscience this the prourment and his all that which it nat, and nature of the distance of the more charm, they accorration, and which that in the spiritful the truths it is man and shame men are such from it properion an
# ----- diversity: 1.0
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which mind, if im
# earing meny, the haps as man feeling in whatinage abil bleay poress apsibild, they
# ither remome, this worak when access upour that explavaition agains that it wele, the low find at evolly a a moreay, there of nery;--and everyesa. which prosrigic us aloursely and intincity." but to truthmen. son, is will.
#
#
# 123
#
# """is diing are mich
# a
# morer. is prusiksed coll due uneathing denount[-s
# ----- diversity: 1.2
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which,-man the! those abounftrenthy, and, are instinction. thas
# is high pursoupelvkinaunedor to
# in a amorhe;
# upon nikeed the, at nlable amity that with le greni prout are of am; deare: but "sbare, with pre"
# find usabolity why
# kremmant, them
# e, hemet bein that become stick along; accuinal ch,lay which or human an(ary sour as
# that the enration, of
# possict--yea or dimpthire cunsecreans solews, aiglt its
# 200285/200285 [==============================] - 140s 697us/sample - loss: 1.9586
# Epoch 2/4
#  - ETA: 6s - loss: 1.6161
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a latter and end of the subjectly and the such a substations of the such a prositions of the still to the sense of the self--and despire to the sense of the sense of the souther of the self--and the subjection, and and the something and reading of the does to the world and the such a prosention of the sole and and the strength of the such a superfice to the self--and the still of the sole the stronger
# ----- diversity: 0.5
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a last the side of the religions and the old things consitence and essential most conception of still personal the sever the same fingled the which is notions of the sages of the prosise to prospins of the encise of the examber to looker and specially fore of one to "still will in the dey all unan ence of the against be the engled are consistions and fore intellect and be and etengent and any the "lig
# ----- diversity: 1.0
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a law win to epent ourselves here"w"; i
# philosophy of the quist simpleamentk--who which
# evioring treems to sboke trectly
# with lother ooupones standingless: in it say an manibewger possible? in
# the
# froeg in ceritive--have does manes will in the still of earteen a, anjesh to the elament are muls the "meadors one menkearal":--of even ancerion: and
# for a streims, and us insti-mysiol, as even
# sirty--is con
# ----- diversity: 1.2
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a latter
# therepelve
# maving and derew apthece to profengestonger "sman, accust, the concernion of
# blook refoy
# heay, the proborous permently, friedmby onlfrengt-fonever deppessially, most--2wecking in
# reslentance enous longrow regadea!,"--that regomsestinge" and-constitation of
# man susanntetiees as he dreating, vent,--sub9le," knowledge:
# in loodigation of easly, and namalately manb!orod aboption. as the
# 200285/200285 [==============================] - 140s 700us/sample - loss: 1.6142
# Epoch 3/4
#  - ETA: 7s - loss: 1.5272
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocration of the moral and perhaps that it is a sense that it is a sense of the pather of the sense of the moral that the more of the sense that it is the pather in the sense of the power the sense of a more of the moral to the partical their conscience of the more that the moral of the most did and delight of the sense in the destraint of the present and an action of the moral and the sense of the par
# ----- diversity: 0.5
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocrations. the most because and spiritual, the best burded the canger, in the procher and himself but and sense to a perhaps to phend, and therefore who and speak and bad and develops him                                                                                for it the science in the destraicture of respectary from its self-and a could so ever expressive in the most precised entire and intermi
# ----- diversity: 1.0
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocratingsh other" and more creas?"
# in ideal."
#
# kindike resideres adzict, who are appear approed (their causts wrusudian?" it must deferest to behed beound looks middentarily nay the
# exalnce in pleasure is myn"which willnger amitely event cildical psy wholing, is that heave, and men of fund of very
# hant nesseriss didend to the
# .there. to the knew great to did to its else have once the herrol in spiritl
# ----- diversity: 1.2
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocrations,
# hitherto offeasured.
# hev mentarbaless
# bud tewdabley for ipmors
# to lom, strenger which beincted not policgphudful menting--in whome do not deed! a etictr:
# dimstinct and she; kor." a cultured rarely hithertial gre instoncencted man imsequect (on loves
# deted itientable, but fund thought
# nowarsval nlithes changliserive
# wime of it--perhaps fluire?
# it is vilwnou, uppectionual
# 'n-tencifical adules
# 200285/200285 [==============================] - 137s 682us/sample - loss: 1.5300
# Epoch 4/4
#  - ETA: 48s - loss: 1.4807
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless and the strength of the prosirity of the streasure his own strength of the same and his own condition of the problem of the prosirion in the strength of the streasure of the strength of the morality and origin of the same to the sense of the still and all the striven and have and all the strength and so in the word and in the strength of the soul and world of the strength and with such a standar
# ----- diversity: 0.5
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless as the philosophers and self-deness and and have be
# instinct and an artistic life to the profound in the pression of its artal, it was the result in the condition. he who himself conscience and so we he say and an exciple, and in no man when they afferreally be consciousness of the sense of
# truesty and to to be together may and his own self-morality that the
# inflicted, so the words of the morali
# ----- diversity: 1.0
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless. herd and operation all  nespead by
# educated they, we contrads wad which en eersial canters from whyn underitaness "mostofients aim menlink, assestoments; and effects,
#  , man in which part
# own dender in the wine
# this wishes.
#
# a
# d belong hooved most betre changety of the rewine, has love as we make time may in how peaces, into knough themevert for himself by transte still, cless taken in ramity.
# ----- diversity: 1.2
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unlessful will pleiciin of
# rescretar. together be dyil of a constantly as arcsn eiribermings afts a of strong,
# hly attentions: that we alwage does nequence of this .--hitherto
#  ?
#
#
#
#
#
# yt has at atterminges, althiegly right and
# : to the
# congraon for him wished, hought stands,os!
#
#  spiratien tente do nature of way.--a contrans in goes ye pleass franme, per"and
# one, only art we lapkafness--has his, egoib
# 200285/200285 [==============================] - 136s 677us/sample - loss: 1.4839

# %%
from numpy import *

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear200.h5')


def lstm_generate(seed, model):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
# seed = "thou art"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the subjections of the subjection of the subjection of the sense of the subjection of the such a particularly the subjection of the subjection of the subjection of the sense of the present the passes of the subjection of the sense of the so the subjection of the more to the subjection of all the like the present to the subjection of the states the subjection of the subjection of the subjection of t
# ----- diversity: 0.5
# ----- Generating with seed: "of the subjection of the subjection of t"
# of the subjection of the subjection of the even about that the subjection of it the community when he was the subjection of the to so far about the seen there is a mustic come the like the confiding and the
# children--and such the more the particularly, what is to the probably the forces of the so far of such the present and the sense to the nature. the ends only a propaciates of merely the present in the
# present in the so called and the
# ----- diversity: 1.0
# ----- Generating with seed: " in the
# present in the so called and the"
#  in the
# present in the so called and the mas nolled fehision chance to these develops
# have it is the worldest tencein and song the devinced.itimingloging with a pheasies. it is hear or. the like
# i affidial demangrous to aby naturance, is to germans the passe,
# with this learly men to aleary called carefully out or wat like with rapar in the newly upon the charminess, and because the way, thste and abuteded a can of
# prequest pro"sons of p
# ----- diversity: 1.2
# ----- Generating with seed: "abuteded a can of
# prequest pro"sons of p"
# abuteded a can of
# prequest pro"sons of pposeth, is bagual nouled,"s, this he offerms of world, that the crefinisyric.
# still matestlined to
# have properrom of man, theregoxiest with the
# rathersicred to every pathe exherasidificure--as nobil impulsed stepshting, a
# bloves of arbinarly all
# which would be anverohy of this catementouse"--whan is
# terpomsble man, amrears it to power--as to love
# might nair, greatest owring
# than this
# of great alon
# Using TensorFlow backend.

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The baby name data set contains 8000 names. You can download and process the name data set as follows:
#
# ``` python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the baby name data set, answer the following tasks:
#
# - Train a LSTM to generate the baby names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?

# %%
#need future import print function?
import tensorflow as tf
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
tf.compat.v1.enable_eager_execution()
name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
with io.open(name_path, encoding='utf-8') as f:
    raw_text = f.read() # make it all lowercase

split_text = raw_text.split()
joined_text = ', '.join(split_text)

text= joined_text # for on_epoch_end

# %%
def vectorize_data_into_x_and_y(text):
    chars = sorted(list(set(text)))
    print('total chars:', len(chars))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    
    
    maxlen = 25
    step = 2
    sentences = []
    next_chars = []
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
    print('nb sequences:', len(sentences))
    
    # Turn these sentances into one-hot encoded vectors
    ## For all words in the sentances, there is a one, else there is a zero in that index of the vector
    
    print('Vectorization...')
    x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
    print('Done!')
    
    return x, y, maxlen, chars, char_indices, indices_char

x, y, maxlen, chars, char_indices, indices_char = vectorize_data_into_x_and_y(joined_text)
# Out:
# total chars: 58
# nb sequences: 250882
# Vectorization...
# Done!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=8,
          callbacks=[print_callback],
          use_multiprocessing=True,
          workers=16)
# Out:
# Train on 250882 samples
# Epoch 1/8
#  - ETA: 1:41 - loss: 2.5146
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: ", Debera, Debernardi, Deb"
# , Debera, Debernardi, Deber, Deber, Deber, Deber, Deber, Deber, Deber, Deberi, Deber, Deber, Debin, Debing, Debing, Debinge, Debing, Debinge, Debine, Debine, Debing, Debinge, Debing, Debins, Debins, Debinger, Debinger, Debin, Debing, Debinger, Debinger, Debins, Debing, Debinge, Debinge, Debinger, Debins, Debinge, Debine, Debing, Debin, Debing, Debing, Debinger, Debine, Debine, Debins, Debinge, Debin, Debing, Debing, Debin
# ----- diversity: 0.5
# ----- Generating with seed: ", Debera, Debernardi, Deb"
# , Debera, Debernardi, Debale, Deballi, Debal, Deban, Debale, Deban, Debalin, Debanich, Debarin, Debato, Debas, Decaman, Decaman, Decan, Deca, Deca, Decara, Decard, Decarico, Decaria, Deca, Deca, Deca, Decace, Decas, Deca, Decacz, Decana, Decane, Decano, Decance, Decan, Decane, Decare, Decaria, Decari, Decar, Deca, Decano, Decane, Decard, Decari, Decari, Decala, Decanan, Decane, Decari, Decarico, Decarle, Decarie, Decarle,
# ----- diversity: 1.0
# ----- Generating with seed: ", Debera, Debernardi, Deb"
# , Debera, Debernardi, Deballama, Dealyne, Dealni, Deangeye, Deania, Deamna, Dean, Deanewski, Deenford, Deemigen, Deimoncla, Deimorn, Deim, Deil, Deind, Deineino, Deint, Deipner, Deisomi, Deirs, Deirman, Deirmarn, Derils, Dering, Derin, Dering, Derort, Derpo, Derro, Derry, Derrti, Dertwort, Derttma, Dertowosz, Derton, Dervrna, Derwent, Derzlor, Derzeke, Derzoi, Detzad, Detzogoe, Detz, Detola, Detone, Detowek, Detoson, Deta
# ----- diversity: 1.2
# ----- Generating with seed: ", Debera, Debernardi, Deb"
# , Debera, Debernardi, Debi, Dezir, Devingalla, Devido, Deviy, Detly, Devce, Decre, Deckard, Depchs, Decktge, Decluchigh, Decigan, Decigere, Decf, Decbegoen, Decdbuugh, Decncz, Decubecz, Decdet, Deddca, Dedgdos, Dedietsa, Dedidranto, Dedmanggre, Dedley, Dedmigfer, Dendrise, Dendryn, Denklann, Denkner, Denkmauncz, Denkmeag, Denes, Denecey, Denentilune, Dennichanna, Denney, Denk, Denkath, Denkin, Denkmanier, Denkowski, Denkm
# 250882/250882 [==============================] - 124s 495us/sample - loss: 1.2776
# Epoch 2/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.8788
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "litz, Klitzke, Kloberdanz"
# litz, Klitzke, Kloberdanz, Kloder, Klodinski, Klodle, Klodler, Klodler, Klodler, Klodler, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder, Kloder,
# ----- diversity: 0.5
# ----- Generating with seed: "litz, Klitzke, Kloberdanz"
# litz, Klitzke, Kloberdanz, Kloder, Kloder, Kloder, Klodi, Klodle, Kloe, Kloel, Kloell, Klole, Kloley, Klolin, Kloling, Kloling, Klolinger, Klolm, Klolin, Klolin, Klolinger, Klolin, Kloling, Kloling, Kloling, Klolings, Kloline, Klolin, Kloll, Klole, Klole, Kloli, Klolin, Klolman, Kloling, Kloll, Klole, Klole, Klole, Kloley, Kloller, Klole, Kloley, Kloli, Klolin, Kloling, Kloling, Kloling, Kloling, Kloling, Klolinger, Kloll
# ----- diversity: 1.0
# ----- Generating with seed: "litz, Klitzke, Kloberdanz"
# litz, Klitzke, Kloberdanz, Klofer, Kloker, Kloley, Klolhi, Klolk, Klolney, Kloly, Kloka, Kloke, Klole, Kmoll, Kloins, Klopker, Kloss, Klossen, Klosey, Kloshen, Klosheel, Kloske, Klosk, Klosa, Klosch, Kloser, Klosen, Klosken, Kloslin, Kloslet, Klosmann, Klosmorer, Klosn, Klosser, Klot, Klote, Kloterby, Klover, Klouwek, Klourh, Klouding, Klood, Kloon, Kloke, Klom, Klomer, Klomes, Klomback, Klonel, Kloner, Klonder, Klook, Kl
# ----- diversity: 1.2
# ----- Generating with seed: "litz, Klitzke, Kloberdanz"
# litz, Klitzke, Kloberdanz, Klods, Kloead, Klocke, Klockie, Klocking, Klon, Klonette, Klop, Klopel, Klopey, Klooly, Kloo, Klorbus, Klockergogn, Klocel, Klocamik, Klocher, Klock, Klochils, Klock, Klod, Klod, Klodel, Kloeb, Kloedis, Kloek, Kloper, Klopersmirski, Knorff, Knosa, Knose, Knosey, Knosel, Knootta, Knovek, Kzoder, Knolabman, Kmornak, Konk, Konker, Konkhales, Konkum, Konkins, Korn, Korna, Korra, Kor, Kordaon, Kiras,
# 250882/250882 [==============================] - 120s 478us/sample - loss: 0.8788
# Epoch 3/8
# 250752/250882 [============================>.] - ETA: 0s - loss: 0.8214
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " Jensen, Jenson, Jenssen,"
#  Jensen, Jenson, Jenssen, Jent, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, J
# ----- diversity: 0.5
# ----- Generating with seed: " Jensen, Jenson, Jenssen,"
#  Jensen, Jenson, Jenssen, Jenter, Jenters, Jentes, Jentering, Jenteria, Jenterine, Jenterino, Jentering, Jenterhin, Jenter, Jenter, Jenter, Jenter, Jenter, Jentere, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenters, Jenter, Jenter, Jenter, Jenter, Jenter, Jenter, Jenters, Je
# ----- diversity: 1.0
# ----- Generating with seed: " Jensen, Jenson, Jenssen,"
#  Jensen, Jenson, Jenssen, Jenton, Jennun, Jennus, Jennworth, Jenny, Jengmand, Jengon, Jenhel, Jenhaln, Jenhary, Jenia, Jenma, Jenome, Jenpeine, Jentem, Jenter, Jenton, Jenvy, Jenvichel, Jenwick, Jenzer, Jenze, Jex, Jexter, Jewety, Jewiche, Jetomar, Jetzell, Jetzinski, Jetzol, Jetzzer, Jetzezer, Jevhi, Jewote, Jewlin, Jexney, Jey, Jexard, Jeyeley, Jezelaw, Jeyles, Jex, Jex, Jex, Jex, Jexer, Jexter, Jexteler, Jex, Jequike,
# ----- diversity: 1.2
# ----- Generating with seed: " Jensen, Jenson, Jenssen,"
#  Jensen, Jenson, Jenssen, Jensora, Jensy, Jenzek, Jemad, Jemachel, Jemelmar, Jemeoin, Jemeruny, Jemgeley, Jchgek, Jchnerg, Jeynger, Jgy, Jezaan, Jubter, Juchalia, Juchilia, Juchley, Juchlough, Juckow, Juoby, Juoce, Jucy, Juczro, Juaham, Jubough, Juchar, Juknee, Jur, Jure, Jurzeher, Jushba, Jusie, Juskey, Jusken, Jusle, Jutise, Jutt, Jutz, Juatch, Juivonch, Juhl, Juhnllait, Juhsels, Jusiet, Juskerlin, Jushmevich, Jusmer, J
# 250882/250882 [==============================] - 116s 462us/sample - loss: 0.8215
# Epoch 4/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.7894
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "e, Pett, Petta, Pettaway,"
# e, Pett, Petta, Pettaway, Petter, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petterson, Petter
# ----- diversity: 0.5
# ----- Generating with seed: "e, Pett, Petta, Pettaway,"
# e, Pett, Petta, Pettaway, Pettreza, Pettron, Petths, Petters, Petterson, Petters, Petterson, Pettersen, Petterson, Petterson, Petton, Petton, Petts, Pettragan, Pettrett, Pettrett, Pettow, Pettre, Pettes, Petters, Petterson, Petterson, Petterson, Petterson, Pettersey, Petterson, Petterson, Pettes, Pettesse, Petteson, Pettes, Pettesel, Pettes, Pettes, Pettey, Pettin, Pettin, Pettin, Pettin, Pettie, Pettie, Pettigoe, Pettie,
# ----- diversity: 1.0
# ----- Generating with seed: "e, Pett, Petta, Pettaway,"
# e, Pett, Petta, Pettaway, Pettin, Petteling, Petter, Petter, Pettelson, Petterss, Pettert, Petteweld, Petterson, Petterson, Petterson, Petterburg, Petto, Pettyson, Petts, Petter, Petterine, Petth, Pettie, Petthford, Petting, Pettman, Petton, Pettrant, Petts, Pettevron, Pettey, Pettin, Petto, Pettont, Petton, Petur, Petwick, Petocker, Peton, Petrockk, Petoring, Petoul, Petuma, Petropfe, Petrocher, Petrig, Petris, Petsum, P
# ----- diversity: 1.2
# ----- Generating with seed: "e, Pett, Petta, Pettaway,"
# e, Pett, Petta, Pettaway, Pettsee, Pettopalette, Pettertiso, Pettermon, Petterman, Petthen, Petth, eetsch, Pettsee, Pettoresso, Pettonez, Lettongan, Lettrunt, Letzleor, Letzhin, Lezaford, Legna, Lebin, Lealin, Leaminger, Leagmaslie, Leages, Leagerty, Leagarry, Leahrin, Leahman, Leahmein, Laigt, Laichmann, Laims, Lailtion, Lain, Lainberg, Lainbach, Laisammer, Laitebach, Laiter, Laitg, Laittee, Laittek, Laje, Lajocky, Lakas
# 250882/250882 [==============================] - 120s 477us/sample - loss: 0.7894
# Epoch 5/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.7682
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "lgrin, Bulin, Bulkley, Bu"
# lgrin, Bulin, Bulkley, Bull, Bulla, Bulle, Bullen, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Buller, Bullett, Bullette, Bullette, Bullette, Bullette, Bullette, Bullette, Bullette, Bullette, Bullette, Bullette, Bulli, Bullic, Bullin, Bullinger, Bullinger, Bullman, Bullmann, Bullman, Bullmann, Bullman, Bullm
# ----- diversity: 0.5
# ----- Generating with seed: "lgrin, Bulin, Bulkley, Bu"
# lgrin, Bulin, Bulkley, Bull, Bulle, Buller, Bullett, Bullette, Bulling, Bullinger, Bullman, Bullmann, Bullner, Bullon, Bullor, Bullow, Bullu, Bullum, Bullow, Bully, Bully, Bullye, Bully, Bully, Bully, Bult, Bulter, Bulterson, Bulterson, Bulterman, Bulthers, Bulther, Bultman, Bulton, Bults, Bults, Bulty, Bultz, Buly, Buma, Bumale, Bumble, Bumbren, Bumbrout, Bumby, Bumbert, Bumbrook, Bumbough, Bumbrom, Bumbrich, Bumbrough,
# ----- diversity: 1.0
# ----- Generating with seed: "lgrin, Bulin, Bulkley, Bu"
# lgrin, Bulin, Bulkley, Bull, Bulla, Bullaw, Bullens, Buller, Bullenstade, Buller, Bulley, Bullin, Bollinger, Bollison, Bollins, Bollmar, Bollman, Bollman, Bollmarn, Bollmann, Bollichum, Bollin, Bollingille, Bollinger, Bollingham, Bollman, Bollmann, Bollman, Bollsee, Bolltinger, Bolly, Boll-, Bollapank, Bollabaugh, Boland, Bolaniett, Bolandino, Bolare, Bolas, Bolash, Bolbetg, Bolcek, Bolcson, Boldsen, Boldey, Bolden, Bolde
# ----- diversity: 1.2
# ----- Generating with seed: "lgrin, Bulin, Bulkley, Bu"
# lgrin, Bulin, Bulkley, Bullank, Bull, Bullar, Bully, Bulla, Bullfer, Bullvedler, Bully, Bully, Bulum, Bulvers, Bulvanes, Bulvey, Buswood, Bushy, Bushraust, Bushler, Bushmar, Busherman, Bushind, Bushner, Bushouson, Bushins, Busil, Busik, Busking, Busky, Bustel, Busume, Bustlerd, Bustra, Bustr, Bustowstor, Busucia, Busum, Busyan, Busburg, Butbrech, Butcor, Butgrel, Butsett, Butt, Buttrael, Buttz, Butty, Butl, Buther, Buthlu
# 250882/250882 [==============================] - 117s 466us/sample - loss: 0.7682
# Epoch 6/8
#  - ETA: 13s - loss: 0.7480
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "s, Siemer, Siemers, Siemi"
# s, Siemer, Siemers, Sieming, Sieming, Siemon, Sien, Siena, Siena, Siena, Siena, Siena, Siena, Siena, Sienard, Sienant, Siener, Siens, Siensch, Siens, Siens, Sier, Siera, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sieran, Sierand, Sierand, Sieran, Sieran, Sieran, Siera
# ----- diversity: 0.5
# ----- Generating with seed: "s, Siemer, Siemers, Siemi"
# s, Siemer, Siemers, Siemire, Siemon, Siemon, Sieminger, Siemon, Sieman, Sieman, Siemann, Sieman, Siemann, Siemenstein, Sieming, Sieman, Siemann, Siemann, Sieman, Siemann, Siamone, Siamoni, Siamoni, Siamont, Siamon, Siaming, Siamon, Siamine, Siamone, Siamon, Siamon, Siamon, Siamone, Siamont, Siamone, Sian, Sian, Sian-on, Sian-and, Sian-an, Sian-, Siara, Siarda, Siardine, Siarles, Siarle, Siarles, Siarling, Siarly, Siarley,
# ----- diversity: 1.0
# ----- Generating with seed: "s, Siemer, Siemers, Siemi"
# s, Siemer, Siemers, Siemire, Siena, Sienen, Sienon, Sier, Siera, Sierbeng, Sierborn, Sierborn, Sierbugs, Sierbury, Siff, Sirgser, Sigron, Sigrigo, Sigrons, Sigston, Sigts, Sigtz, Sigzell, Sigzo, Sig, Sigan, Sigb, Sigda, Sig,alipa, Sigbindt, Sigak, Sigan, Sigans, Sigchard, Sigham, Sigger, Siggstren, Siggz, Siggy, Sigia, Sighout, Sigman, Signa, Signi, Signall, Signes, Sigonao, Signell, Signetfe, Sihny, Signemen, Signer, Sig
# ----- diversity: 1.2
# ----- Generating with seed: "s, Siemer, Siemers, Siemi"
# s, Siemer, Siemers, Sieming, Siegpter, Siegz, Siffsich, Sigman, Signak, Sigo, Sigott, Sigoodwaugh, Siphton, Wimey, Wimping, Wimpley, Wimpley, Wimpler, Wimpley, Wimplow, Wimpleren, Wimpley, Wimpler, Wimplesherr, Wimpley, Wipliver, Winn, Winner, Winney, Winnington, Winnke, Winn, Winnara, Wintis, Winton, Wintworth, Wintunzer, Wintuy, Wintzel, Widoo, Wiff, Widfield, Wifdlell, Wiffrey, Wiffler, Wifdler, Wiffrestalk, Wiffor, Wi
# 250882/250882 [==============================] - 119s 473us/sample - loss: 0.7497
# Epoch 7/8
# 250752/250882 [============================>.] - ETA: 0s - loss: 0.7354
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "Tessler, Tessman, Tessmer"
# Tessler, Tessman, Tessmer, Tessmann, Tessmannn, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tessner, Tessner, Tessner, Tessner, Tesson, Tessner, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Tesson, Test, Testa, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester,
# ----- diversity: 0.5
# ----- Generating with seed: "Tessler, Tessman, Tessmer"
# Tessler, Tessman, Tessmer, Tessmann, Tessner, Tessner, Tesson, Testrands, Testrance, Tester, Tester, Tester, Tester, Tester, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerlund, Testerman, Testerle, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerman, Testerlin, Testerlie, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Tester, Teste
# ----- diversity: 1.0
# ----- Generating with seed: "Tessler, Tessman, Tessmer"
# Tessler, Tessman, Tessmer, Tesson, Tessona, Tassonder, Tast, Tastas, Taster, Tasterbell, Tastero, Tastering, Tatte, Tatter, Tatthels, Tattnaus, Tatt, Tatte, Tautari, Tawstoin, Tayles, Tan, Tana, Tanato, Tanca, Tancaiilla, Tandaulo, Tand, Tanda, Tandell, Tander, Tandermuta, Tanders, Tandieri, Tandlund, Tandorje, Tandovick, Tandoory, Tandow, Tandra, Tandriw, Tandroff, Tandroff, Tandow, Tands, Tandwick, Tandle, Tandoff, Tand
# ----- diversity: 1.2
# ----- Generating with seed: "Tessler, Tessman, Tessmer"
# Tessler, Tessman, Tessmerll, Tassontas, Tastew, Tastenbert, Taster, Tasterlarriger, Tasti, Tastiga, Tast, Tastalee, Taste, Tastaciso, Tastarde, Tastarro, Tastaro, Tastewein, Tastewson, Tasti, Tasti, Tatsidge, Tatti, Tatta, Tatte, Fattelly, Fattedlandio, Fattermille, Fatsley, Fatsley, Fatsley, Fatson, Fattuse, Fettwerr, Fetteberry, Fertese, Ferto, Fertoni, Ferto, Fertonie, Fertomino, Fertonoso, Fertomuto, Ferty, Frestman,
# 250882/250882 [==============================] - 123s 488us/sample - loss: 0.7354
# Epoch 8/8
#  - ETA: 22s - loss: 0.7165
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ne, Marroquin, Marrow, Ma"
# ne, Marroquin, Marrow, Marruth, Marruth, Marrutt, Marrutt, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marruth, Marrutt, Marrutt, Marrutt, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marrutt, Marrutte, Marrutte, Marrutte, Marrutte, Marrutt, Marrutte, Marrutte, Marrutte, Marrutte, Marrutte, Marruth, Marrutt, Marrutte, Marrutte, Marruth, Marrutt, Marrutt, Marrutte, Marrutte, Marrutt
# ----- diversity: 0.5
# ----- Generating with seed: "ne, Marroquin, Marrow, Ma"
# ne, Marroquin, Marrow, Marruphi, Marrup, Marrum, Marrum, Marry, Marsh, Marshaw, Marshaw, Marshaw, Marshaw, Marshaw, Marsheaf, Marshico, Marshiwa, Marshikawski, Marshow, Marshaw, Marshin, Marshie, Marshir, Marshira, Marshin, Marshin, Marsher, Marshir, Marshire, Marshino, Marshira, Marshiro, Marsham, Marshin, Marshis, Marshie, Marshir, Marshie, Marshow, Marsheam, Marshina, Marshin, Marshick, Marshir, Marshire, Marshie, Mars
# ----- diversity: 1.0
# ----- Generating with seed: "ne, Marroquin, Marrow, Ma"
# ne, Marroquin, Marrow, Marryak, Marsor, Marsich, Marshinghom, Marshimori, Marsheff, Marribe, Marrigatta, Marrill, Marriel, Marqietza, Marhish, Mari, Marica, Maricelli, Marick, Marick, Maricke, Marich, Maricia, Mariick, Marile, Marilla, Marill, Marillan, Marilisio, Marilla, Marimotte, Mariloaco, Marir, Maris, Maristel, Marisson, Marist, Marita, Maritch, Mark, Markob, Markman, Marknick, Markriak, Markricak, Markria, Mark, M
# ----- diversity: 1.2
# ----- Generating with seed: "ne, Marroquin, Marrow, Ma"
# ne, Marroquin, Marrow, Marrusk, Marrysse, Marsota, Marswin, Marschwand, Marsymore, Marswihi, Marszgu, Marseff, Marser, Marsella, Marreau, Marre, Marreca, Marrecita, Marrecuhin-, Marrerceo, Marres, Marrete, Marsentro, Marseto, Marsetti, Marsetta, Marsepe, Marseavan, Marseelea, Marseef, Marreemy, Marreel, Marreltan, Marrehoan, Marrel, Marreca, Marrecaufe, Marredisco, Marrehan, Marreld, Marrelle, Marrellano, Marrer, MarreMca
# 250882/250882 [==============================] - 120s 479us/sample - loss: 0.7233

# %% [markdown]
# Training the baby-name-generator took 895 seconds for 8 epochs, around 112 seconds per epoch.
# I'm not sure if it became more coherent/realistic over this stretch of training because most of the baby names in the training data sound so strange to me that I'm not confident about judging how different one of the network's generated names is from the given dataset of baby names.

# %%
# import keras.utils
# import keras.utils.data_utils
#
# class ShufflePerEpochSequence(keras.utils.data_utils.Sequence):
#     def __init__(self, split_text, batch_size):
#         self.split_text = split_text
#         self.batch_size = batch_size
#         self.text = ', '.join(self.split_text)
#         x, y, maxlen, chars, char_indices, indices_char = vectorize_data_into_x_and_y(self.text)
#         self.x = x
#         self.y = y
#         self.epoch= 0
#
#
#     def __len__(self):
#         return int(np.ceil( len(self.x) / float(self.batch_size) ))
#
#
#     def __getitem__(self, index):
#         batch_x = self.x[index * self.batch_size:(index + 1) * self.batch_size]
#         batch_y = self.y[index * self.batch_size:(index + 1) * self.batch_size]
#
#         return np.array(batch_x), np.array(batch_y)
#
#
#     #todo copy in vectorize_data... function?
#     def __vectorize_data_into_x_and_y(self, text):
#         chars = sorted(list(set(text)))
#         print('total chars:', len(chars))
#         char_indices = dict((c, i) for i, c in enumerate(chars))
#         indices_char = dict((i, c) for i, c in enumerate(chars))
#
#
#         maxlen = 25
#         step = 2
#         sentences = []
#         next_chars = []
#         for i in range(0, len(text) - maxlen, step):
#             sentences.append(text[i: i + maxlen])
#             next_chars.append(text[i + maxlen])
#         print('nb sequences:', len(sentences))
#
#         # Turn these sentances into one-hot encoded vectors
#         ## For all words in the sentances, there is a one, else there is a zero in that index of the vector
#
#         print('Vectorization...')
#         x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
#         y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
#         for i, sentence in enumerate(sentences):
#             for t, char in enumerate(sentence):
#                 x[i, t, char_indices[char]] = 1
#             y[i, char_indices[next_chars[i]]] = 1
#         print('Done!')
#
#         return x, y, maxlen, chars, char_indices, indices_char
#
#     def __sample(self, preds, temperature=1.0):
#         # helper function to sample an index from a probability array
#         preds = np.asarray(preds).astype('float64')
#         preds = np.log(preds) / temperature
#         exp_preds = np.exp(preds)
#         preds = exp_preds / np.sum(exp_preds)
#         probas = np.random.multinomial(1, preds, 1)
#         return np.argmax(probas)
#
#     def on_epoch_end(self):
#         shuffled_split_text = random.shuffle(self.split_text)
#         self.text = ', '.join(shuffled_split_text)
#         x, y, maxlen, chars, char_indices, indices_char = self.__vectorize_data_into_x_and_y(self.text)
#         self.x = x
#         self.y = y
#
#         print()
#         print('----- Generating text after Epoch: %d' % self.epoch)
#
#         start_index = random.randint(0, len(self.text) - maxlen - 1)
#         for diversity in [0.2, 0.5, 1.0, 1.2]:
#             print('----- diversity:', diversity)
#
#             generated = ''
#             sentence = self.text[start_index: start_index + maxlen]
#             generated += sentence
#             print('----- Generating with seed: "' + sentence + '"')
#             sys.stdout.write(generated)
#
#             for i in range(400):
#                 x_pred = np.zeros((1, maxlen, len(chars)))
#                 for t, char in enumerate(sentence):
#                     x_pred[0, t, char_indices[char]] = 1.
#
#                 preds = model.predict(x_pred, verbose=0)[0]
#                 next_index = self.__sample(preds, diversity)
#                 next_char = indices_char[next_index]
#
#                 generated += next_char
#                 sentence = sentence[1:] + next_char
#
#                 sys.stdout.write(next_char)
#                 sys.stdout.flush()
#             print()
#
#         self.epoch += 1

# %%
# shufflingDataSequence = ShufflePerEpochSequence(split_text, 128)
# print(isinstance(shufflingDataSequence, keras.utils.Sequence))
# print(isinstance(shufflingDataSequence, keras.utils.data_utils.Sequence))

# %%
# model.run_eagerly = True
# model._experimental_run_tf_function = (False)
# model.fit_generator(generator=shufflingDataSequence, epochs=8) #,
          # use_multiprocessingssing=True,
          # workers=16)
model.fit(x, y,
          batch_size=128,
          epochs=8,
          callbacks=[print_callback],
          use_multiprocessing=True,
          workers=16,
          shuffle=True)
# Out:
# Train on 250882 samples
# Epoch 1/8
#  - ETA: 1:17 - loss: 0.6827
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ush, Furby, Furches, Fure"
# ush, Furby, Furches, Fure, Furen, Furent, Furer, Furger, Furger, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgert, Furger, Furger, Furgers, Furgers, Furgers, Furges, Furgers, Furger, Furgers, Furges, Furges, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furgers, Furges, Furges, Furges, Furges, Furger, Furgers, Furgers, Furgers, Fu
# ----- diversity: 0.5
# ----- Generating with seed: "ush, Furby, Furches, Fure"
# ush, Furby, Furches, Fure, Furek, Furk, Furker, Furkerts, Furking, Furks, Furl, Furland, Furley, Furlon, Furoll, Furold, Furrie, Furritt, Furroy, Furry, Furt, Furte, Furten, Furter, Furter, Furti, Furunde, Furus, Furwell, Fury, Fus, Fuske, Fuskin, Fusler, Fuster, Fuster, Fusterman, Fusterman, Fusters, Fusterman, Fusters, Fuster, Fuster, Fusterman, Fusterman, Fusters, Fusterson, Fusterman, Fusterman, Fusterman, Fusters, Fu
# ----- diversity: 1.0
# ----- Generating with seed: "ush, Furby, Furches, Fure"
# ush, Furby, Furches, Fure, Furman, Furm, Furman, Furnef, Furnudo, Furnstaff, Furso, Furby, Fure, Furhoff, Furke, Furkine, Furks, Furl, Furland, Furles, Furlin, Furly, Furlyn, Furd, Furdle, Furdra, Furras, Furrass, Furrenhars, Furrie, Furris, Furry, Furtner, Fury, Fus, Fusely, Fusebla, Fuser, Fush, Fusia, Fusia, Fusia, Fuslin, Fushuch, Fushau, Fushards, Fusrick, Fusham, Fusher, Fusherman, Fushman, Fushman, Fuskivior, Fussn
# ----- diversity: 1.2
# ----- Generating with seed: "ush, Furby, Furches, Fure"
# ush, Furby, Furches, Furel, Furler, Furleys, Furlakiro, Furlam, Furkes, Furkeglahe, Furko, Furman, Furo, Furs, Fursuma, Furstome, Furstona, Furstram, Furky, Furgillo, Futland, Futrdaoor, Futke, Futi, Futebla, Futak, Futel, Futett, Futlio, Futobs, Futolz, Fut, Futepp, Futepinto, Futili, Futley, Fut, Futpask, Futwell, Futhwith, Futinp, Futoniden, Futoen, Fuznion, Fus, Fussbei, Fuska, Fuski, Fusky, Fuski, Fust, Fusting, Fust
# 250882/250882 [==============================] - 121s 482us/sample - loss: 0.7121
# Epoch 2/8
# 250752/250882 [============================>.] - ETA: 0s - loss: 0.7027
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "er, Radebaugh, Radecki, R"
# er, Radebaugh, Radecki, Radele, Radelin, Radelli, Radello, Radelli, Radelli, Radello, Radelli, Radelli, Radelli, Radello, Radelli, Radelli, Radelli, Radelli, Radello, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radello, Radelli, Radelli, Radelli, Radello, Radello, Radelli, Radelli, Radelli, Radelli, Radelli, Radelli, Radello, Radelli, Radelli, Radelli, Radello, Radell
# ----- diversity: 0.5
# ----- Generating with seed: "er, Radebaugh, Radecki, R"
# er, Radebaugh, Radecki, Radeland, Radelino, Radelin, Radello, Radeletti, Radelino, Radelino, Radelino, Radeli, Radelino, Radelli, Radelino, Radelino, Radeling, Radell, Radelli, Radelli, Radelli, Radello, Radella, Radello, Radelli, Radello, Radelle, Radelli, Radelino, Radelino, Radelino, Radelino, Radeling, Radelinger, Radell, Radello, Radelli, Radello, Radelli, Radelli, Radelino, Radelino, Radelino, Radele, Radelin, Radel
# ----- diversity: 1.0
# ----- Generating with seed: "er, Radebaugh, Radecki, R"
# er, Radebaugh, Radecki, Radee, Radee, Radell, Raden, Radonne, Rador, Radoso, Rada, Radanra, Radani, Radao, Rada, Radall, Radan, Radan, Radanton, Radano, Radara, Rade, Radila, Radison, Radino, Radinglak, Radizet, Radling, Radley, Radolins, Rado, Radolo, Radya, Radlescont, Radling, Radminger, Rado, Radona, Radone, Radonne, Radoz, Rade, Radel, Radelli, Radello, Radelece, Radeler, Radelill, Radell, Radello, Radello, Radelette
# ----- diversity: 1.2
# ----- Generating with seed: "er, Radebaugh, Radecki, R"
# er, Radebaugh, Radecki, Radebaw, Radgario, Raddie, Raddis, Raddy, Raycecrace, Radcaghia, Radcoiino, Rade, Radel, Radell, Radenbaugh, Radeen, Radele, Radelfond, Radelgams, Radelek, Radelet, Radelt, Radeltino, Radeltuma, Radelle, Radelik, Radelus, Rdager, Rdage, Ragas, Raga, Ragell, Ragely, Ragelip, Rgeling, Rgelk, Remell, Remeo, Remeaue, Remed, Remenx, Remes, Remieau, Remiekson, Remildeuvar, Remmie, Remmisa, Remmingerman,
# 250882/250882 [==============================] - 118s 469us/sample - loss: 0.7027
# Epoch 3/8
#  - ETA: 28s - loss: 0.6847
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "Lares, Larew, Large, Larg"
# Lares, Larew, Large, Larger, Larges, Largester, Largester, Largess, Largess, Largester, Largester, Largester, Largester, Largester, Largi, Laricino, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Larick, Lari
# ----- diversity: 0.5
# ----- Generating with seed: "Lares, Larew, Large, Larg"
# Lares, Larew, Large, Largell, Largen, Largenstein, Larges, Larges, Largie, Larigo, Larilla, Larin, Larina, Larina, Larine, Laris, Larish, Lariss, Larisz, Larisse, Larissa, Larison, Larissa, Larissa, Larist, Larisi, Larisse, Larissa, Larisse, Lariso, Larissa, Larisz, Larisse, Larissa, Larissa, Larissa, Larissa, Larissa, Larissa, Larisa, Larissa, Larisse, Lariss, Larissa, Larisse, Larissa, Lariso, Larissa, Lariso, Larison,
# ----- diversity: 1.0
# ----- Generating with seed: "Lares, Larew, Large, Larg"
# Lares, Larew, Large, Largels, Largenstein, Largeaux, Largical, Largham, Mari, Maria, Mariass, Maricza, Marice, Marigosa, Maril, Marilsne, Marikosne, Mariko, Marima, Marina, Marindo, Mariona, Maris, Marisfield, Marise, Marison, Mariso, Marista, Marisut, Mariso, Mariso, Marisy, Marissa, Marissio, Marisja, Marisua, Marison, Marissa, Marison, Marissa, Marison, Marissa, Marissa, Marissen, Marister, Marisso, Marista, Marista, M
# ----- diversity: 1.2
# ----- Generating with seed: "Lares, Larew, Large, Larg"
# Lares, Larew, Large, Largman, Largout, Largraw, Lariga, Lariette, Laries, Larigue, Laril, Larila, Larine, Larinere, Larinson, Larisch, Larisi, Lark, Larkel, Larde-x, Larden, Lardsea, Lardstone, Lardosfied, Lardhis, Lardiene, Lardingui, Lardine, Lardinger, Lardman, Lardner, Lardner, Lardner, Lardman, Lardmarn, Lardon, Lardano, Lardane, Lardano, Lardanin, Lardani, Larelda, Laremereo, Larenzo, Largom, Lare, Largay, Larhas, L
# 250882/250882 [==============================] - 116s 464us/sample - loss: 0.6940
# Epoch 4/8
# 250752/250882 [============================>.] - ETA: 0s - loss: 0.6860
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "chmann, Fleisher, Fleishm"
# chmann, Fleisher, Fleishman, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Fleiser, Flelski, Flelstrom, Flemsen, Flems, Flems, Flems, Flems, Flems, Flener, Flenick, Flenick, Flenick, Fless, Fless, Flesser, Fless, Flesser, Flesser, Flesser, Flesser, Flesser, Flesser, Flesser, Fless, Fless, Flessel, Flesser, F
# ----- diversity: 0.5
# ----- Generating with seed: "chmann, Fleisher, Fleishm"
# chmann, Fleisher, Fleishman, Fleise, Fleiser, Fleiser, Fleiser, Fleisee, Fleiser, Flelster, Flesh, Flesh, Fless, Flesseal, Flessi, Fless, Flesser, Fless, Flessbury, Flesser, Flesser, Fleston, Flett, Flever, Flevers, Fleverson, Flevi, Flevine, Flevine, Flevina, Flevo, Flewner, Flewner, Flewner, Flewner, Flewinski, Flewski, Flukas, Fluck, Flucker, Fluck, Flucke, Fluman, Flumh, Flum, Flume, Flunck, Flunder, Flund, Flung, Flu
# ----- diversity: 1.0
# ----- Generating with seed: "chmann, Fleisher, Fleishm"
# chmann, Fleisher, Fleishman, Flemhsetter, Flelklins, Flelkenstein, Flelkerly, Flelkend, Fleker, Fleldrom, Flelivar, Flemmer, Fleming, Flememore, Flemes, Flemming, Flemp, Flemper, Flempel, Flempki, Flempe, Flemper, Flempers, Flempp, Flenka, Flessell, Flsermach, allard, ibins, Fbsharn, Fok, Foke, Fokdshic, Fokkid, Folka, Folkendan, Folking, Folkman, Folko, Folkow, Folks, Fokles, Fomkins, Fomkishey, Fomle, Fommer, Fomont, Fo
# ----- diversity: 1.2
# ----- Generating with seed: "chmann, Fleisher, Fleishm"
# chmann, Fleisher, Fleishmag, Fleisburn, Fleisa, Flecke, Fleten, Flond, Flopan, Flordera, Florginge, Florn, Flosgach, Fluske, Flusl, Flutt, Flutteman, Fluntke, Floutangardt, Fluzara, Flub, Flucke, Flucker, Fludsard, Flukv, Flum, Flwaum, Flusamon, Fluzbare, Fluzman, Flubiny, Fluck, Fluke, Fluklud, Flupra, Flurina, Flus, Fluszewski, Fluz, Flute, Fhuterbesfun, Fhtney, barg, niock, Erkawog, Ernerault, Erlin, Erlows, Erly, Erma
# 250882/250882 [==============================] - 119s 475us/sample - loss: 0.6860
# Epoch 5/8
#  - ETA: 1:21 - loss: 0.6408
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "t, Archard, Archbold, Arc"
# t, Archard, Archbold, Archen, Archens, Archer, Archers, Arches, Arches, Archett, Arches, Arches, Arches, Archey, Archie, Archin, Archold, Archold, Archold, Archold, Archold, Archold, Archoll, Arconi, Arconi, Arconi, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arcono, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arconio, Arc
# ----- diversity: 0.5
# ----- Generating with seed: "t, Archard, Archbold, Arc"
# t, Archard, Archbold, Archen, Archens, Arches, Archesen, Archett, Archiel, Archotte, Archolli, Arcolone, Arconio, Arcona, Arcone, Arconne, Armanski, Armans, Armas, Armbrill, Armbroque, Armbroque, Armburg, Armburg, Armbron, Armbrooks, Armburs, Arme, Armell, Armelson, Armenschen, Armer, Armey, Armi, Armich, Armichelle, Armico, Armicio, Armicolone, Armison, Armos, Armoy, Armont, Armons, Arnan, Arnan, Arnante, Arne, Arnebell,
# ----- diversity: 1.0
# ----- Generating with seed: "t, Archard, Archbold, Arc"
# t, Archard, Archbold, Arche, Archeman, Archemen, Arcsey, Arci, Arcianna, Arcinelli, Arco, Arda, Ardazie, Ardaulla, Ardebanne, Ardeaux, Ardegro, Ardedredi, Ardeen, Ardela, Ardenson, Ardi, Ardis, Ardita, Ardizai, Ardmal, Ardo, Ardon, Ardy, Ardyl, Are, Areber, Aree, Areek, Areld, Areon, Arenoglio, Arescone, Aresha, Aretsk, Arette, Aretonde, Arethine, Arethill, Aretta, Aretta, Areyl, Are, Areazai, Areda, Areanne, Areanea, Are
# ----- diversity: 1.2
# ----- Generating with seed: "t, Archard, Archbold, Arc"
# t, Archard, Archbold, Archerco, Archiewich, Archur, Arcitlersen, Arckstopa, Arcula, Arcroum, Arckyshin, Arcks, Arckson, Arckson, Arckwont, Arcer, Arcciene, Archce, Archer, Arcshitte, Arciscmes, Arcti, Armyan, Arn, Arnbarger, Arnburd, Arnburs, Arnczzyns, Arnus, Arojib, Arolak, Arol, Aron, Arorre, Arrelle, Arrid, Arrilhanissa, Arslerick, Arsmeier, Arsoo, Arsor, Arss-x, Arrucko, Arsuls, Arsuado, Arsta, Arstene, Arsmetts, Ars
# 250882/250882 [==============================] - 123s 492us/sample - loss: 0.6787
# Epoch 6/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.6732
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: " Stampley, Stamps, Stan, "
#  Stampley, Stamps, Stan, Stana, Stanar, Stanart, Stanas, Stanch, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stancher, Stanchert, Stancher, Stancher, Stancher, Stancher, Stancher,
# ----- diversity: 0.5
# ----- Generating with seed: " Stampley, Stamps, Stan, "
#  Stampley, Stamps, Stan, Stance, Stanch, Stancher, Stancher, Stancher, Stanchin, Stanching, Stanchs, Stanck, Stand, Standa, Standa, Standain, Standary, Standrack, Standree, Standrick, Standrickson, Stang, Stanger, Stang, Stangel, Stanger, Stanger, Stangert, Stanger, Stangert, Stangers, Stanger, Stangert, Stanger, Stanger, Stanger, Stanger, Stanger, Stanger, Stanger, Stanger, Stanger, Stangert, Stanger, Stangert, Stanger,
# ----- diversity: 1.0
# ----- Generating with seed: " Stampley, Stamps, Stan, "
#  Stampley, Stamps, Stan, Stanch, Standa, Stander, Standorik, Stanethill, Stanes, Stangalt, Stangala, Stanger, Stangert, Stangett, Stanger, Stangler, Stango, Stangus, Stangzyo, Stangstrom, Stangubski, Stangser, Stanguin, Stangoit, Stanka, Stand, Standen, Stander, Standiar, Standieri, Standis, Stanburi, Stangacht, Stanberg, Stanforth, Standy, Stane, Stanecher, Stanefer, Stanehan, Stanfield, Stangallan, Stangeline, Stangle,
# ----- diversity: 1.2
# ----- Generating with seed: " Stampley, Stamps, Stan, "
#  Stampley, Stamps, Stan, Stanagan, Stanah, Stanar, Stanberger, Stanburtz, Stanch, Stancocimo, Standa, Standab, Standar, Standranz, Standrie, Standy, Stane, Stanber, Stanburs, Stanch, Stancheon, Stanchi, Stanck, Standel, Standler, Stanel, Standion, Standmi, Staneart, Stanpier, Stanus, Stancia, Stancy, Stanek, Stanek, Staner, Stanfors, Stanoin, Stanoe, Stants, Stanty, Staoad, Stauda, Stade, Stadey, Staefert, Staeford, Staeg
# 250882/250882 [==============================] - 122s 485us/sample - loss: 0.6732
# Epoch 7/8
#  - ETA: 12s - loss: 0.6612
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: ", Dingler, Dingley, Dingm"
# , Dingler, Dingley, Dingman, Dingper, Dings, Dini, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dining, Dink, Dinken, Dinkenberg, Dinker, Dinkers, Dinkers, Dinkers, Dinkers, Dinkle, Dinkler, Dinkler, Dinkley, Dinkler, Dinkley, Dinkley, Dinkley, Dinkley, Dinkley, Dinkley, Dinkley, Dinkler, Dinkler, Dinkley, Dinkley, Dinkler, Dinkler, Dinkler, Dinkler, Dinkler, Dinkler, Dinkler, Di
# ----- diversity: 0.5
# ----- Generating with seed: ", Dingler, Dingley, Dingm"
# , Dingler, Dingley, Dingman, Dingold, Dingron, Dini, Dinico, Dinig, Dininger, Dink, Dinken, Dinkenberg, Dinken, Dinker, Dinkiewicz, Dinkle, Dinkler, Dinkler, Dinkler, Dinkler, Dinkler, Dinkley, Dinkler, Dinkle, Dinkley, Dinkley, Dinkley, Dinkler, Dinkler, Dinkley, Dinkle, Dinkler, Dinkler, Dinkle, Dinkley, Dinkley, Dinkley, Dinkke, Dinkler, Dinkle, Dinkler, Dinkle, Dinkler, Dinkle, Dinkley, Dinkler, Dinkley, Dinkler, Dink
# ----- diversity: 1.0
# ----- Generating with seed: ", Dingler, Dingley, Dingm"
# , Dingler, Dingley, Dingmaire, Dingulia, Dini, Dinil, Dinina, Dinini, Dininia, Dining, Diningont, Dino, Dinough, Dinson, Dintea, Dinton, Dinton, Dintner, Dinton, Dintrowh, Dintz, Dionito, Dioth, Dipantos, Dippette, Dipphardton, Dipreis, Diprock, Dipnaly, Dipper, Dipps, Dipsey, Dipstone, Dipto, Dipapella, Dipier, Dipes, Dipieralle, Dipil, Diping, Dipne, Dippy, Dips, Dipsham, Dipshaelt, Dipsha, Dipsleer, Dipski, Dimsky, Dim
# ----- diversity: 1.2
# ----- Generating with seed: ", Dingler, Dingley, Dingm"
# , Dingler, Dingley, Dingman, Dini, Dink, Dinke, Dinkenrall, Dinkel, Dinkee, Dilnen, Dinzer, Dilsrigg, Dilvers, Dilper, Dimarg, Dimock, Dimmucuk, Dims, Dimppey, Dimpman, Dimonta, Dimoto, Dimay, Diydella, Dimver, Dimeon, Dimit, Dimiaarco, Dimjel, Dimki, Dimmer, Dimmer, Dimmergeal, Dimmernock, Dimmon, Dimmstrobh, Dimn, Dimp, Dimbaugh, Dimhembepn, Dimho, Dimith, Dimilla, Dimlie, Dimotelsen, Dimmros, Dimsnette, Dimster, Dick,
# 250882/250882 [==============================] - 137s 548us/sample - loss: 0.6672
# Epoch 8/8
#  - ETA: 24s - loss: 0.6577
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "Bouler, Boulet, Boulette,"
# Bouler, Boulet, Boulette, Boulthorne, Boulton, Boulton, Bouman, Boumann, Boumant, Boumant, Boumer, Boumer, Boumer, Boumer, Boumer, Boumes, Boumes, Boumette, Boumier, Boumont, Boumund, Boumurd, Boun, Bound, Bounder, Boundy, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Boungle, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Bounger, Boun
# ----- diversity: 0.5
# ----- Generating with seed: "Bouler, Boulet, Boulette,"
# Bouler, Boulet, Boulette, Boulther, Boulton, Bouman, Boumann, Boune, Bounham, Bounger, Bounger, Bousch, Bouse, Boush, Bousher, Bousfeld, Bousler, Boutan, Boutcher, Bouther, Bouthert, Bouthner, Bouthert, Bouthert, Bouthert, Boutherry, Boutherly, Bouther, Bouthler, Bouthlam, Boutles, Bouthum, Bouthman, Bouthwell, Bouthner, Bouther, Bouthens, Bouthers, Bouthers, Boutherman, Bouther, Bouthner, Bouthers, Bouthert, Bouthert, Bo
# ----- diversity: 1.0
# ----- Generating with seed: "Bouler, Boulet, Boulette,"
# Bouler, Boulet, Boulette, Boulhersen, Boulringer, Boum, Bouree, Bouren, Bous, Bouse, Boush, Boush, Boust, Boussbuon, Bousseach, Boussel, Bouswell, Bousz, Bou, Bougam, Bough, Boughba, Bougher, Boughner, Bougher, Bougher, Bouhenly, Bouhler, Bouldievar, Boulett, Boulla, Boultin, Bouly, Boum, Boumange, Bouman, Boumer, Boumogsen, Boumory, Boumargh, Boun, Bouse, Bouse, Bousm, Bousler, Boutl, Botzler, Botzell, Botzler, Bou, Boma
# ----- diversity: 1.2
# ----- Generating with seed: "Bouler, Boulet, Boulette,"
# Bouler, Boulet, Boulette, Bouserla, Bouxigine, Bouvoda, Bovosia, Bovrey, Bodrotti, Bodwort, Boe, Boeber, Boebert, Boe, Boeba, Boebeier, Boeber, Boede, Boedeen, Boedel, Boecien, Boema, Boday, Bode, Bodel, Bodee, Bodetta, Bodertho, Bodey, Boehord, Boehury, Boehn, Boehind, Boehnee, Boehnina, Boehmte, Boehm, Boehle, Boehn, Boek, Boekl, Boelle, Boeller, Boeley, Boenbeter, Boemus, Boepler, Boetch, Boetche, Boett, Boen, Boene, B
# 250882/250882 [==============================] - 130s 520us/sample - loss: 0.6633

# %% [markdown]
# Adding the data-shuffling between epochs increases the training time to 986 seconds for 8 epochs, around 123 seconds per epoch.
# As before, I'm not sure if it became more coherent/realistic with shuffling after each epoch of training because most of the baby names in the training data sound so strange to me that I'm not confident about judging how different one of the network's generated names is from the given dataset of baby names.
