# %% [markdown]
# ## Lab 8, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 200285
# Vectorization...
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Training (reduce the number of epochs, it takes a lot of time!!)
# -  Each epoch takes 5-10 minutes or so on a CPU (an epoch took 7.5 minutes for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (2-3 hours)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=4,
          callbacks=[print_callback])
# Out:
# Train on 200285 samples
# Epoch 1/4
#  - ETA: 1s - loss: 1.9631
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which is a man and propers of the hist the more and the spirit and the self the species and the species of the superse of the which the self-experient and provers of the discive and supers and the morality the spirits and propere the some still that it is a reare experience and a propere and the prospres and the prover of the stall and the self-experient and the self of the readous and in the concept
# ----- diversity: 0.5
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which is a mivele are a mare and intention and the propent in there the mrans and in the discaring and the free the concession of the belief and a mast, and as a reading in this the conscience this the prourment and his all that which it nat, and nature of the distance of the more charm, they accorration, and which that in the spiritful the truths it is man and shame men are such from it properion an
# ----- diversity: 1.0
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which mind, if im
# earing meny, the haps as man feeling in whatinage abil bleay poress apsibild, they
# ither remome, this worak when access upour that explavaition agains that it wele, the low find at evolly a a moreay, there of nery;--and everyesa. which prosrigic us aloursely and intincity." but to truthmen. son, is will.
#
#
# 123
#
# """is diing are mich
# a
# morer. is prusiksed coll due uneathing denount[-s
# ----- diversity: 1.2
# ----- Generating with seed: "e ribs ready for the blind rage with whi"
# e ribs ready for the blind rage with which,-man the! those abounftrenthy, and, are instinction. thas
# is high pursoupelvkinaunedor to
# in a amorhe;
# upon nikeed the, at nlable amity that with le greni prout are of am; deare: but "sbare, with pre"
# find usabolity why
# kremmant, them
# e, hemet bein that become stick along; accuinal ch,lay which or human an(ary sour as
# that the enration, of
# possict--yea or dimpthire cunsecreans solews, aiglt its
# 200285/200285 [==============================] - 140s 697us/sample - loss: 1.9586
# Epoch 2/4
#  - ETA: 6s - loss: 1.6161
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a latter and end of the subjectly and the such a substations of the such a prositions of the still to the sense of the self--and despire to the sense of the sense of the souther of the self--and the subjection, and and the something and reading of the does to the world and the such a prosention of the sole and and the strength of the such a superfice to the self--and the still of the sole the stronger
# ----- diversity: 0.5
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a last the side of the religions and the old things consitence and essential most conception of still personal the sever the same fingled the which is notions of the sages of the prosise to prospins of the encise of the examber to looker and specially fore of one to "still will in the dey all unan ence of the against be the engled are consistions and fore intellect and be and etengent and any the "lig
# ----- diversity: 1.0
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a law win to epent ourselves here"w"; i
# philosophy of the quist simpleamentk--who which
# evioring treems to sboke trectly
# with lother ooupones standingless: in it say an manibewger possible? in
# the
# froeg in ceritive--have does manes will in the still of earteen a, anjesh to the elament are muls the "meadors one menkearal":--of even ancerion: and
# for a streims, and us insti-mysiol, as even
# sirty--is con
# ----- diversity: 1.2
# ----- Generating with seed: "n and dragon in his cave--it
# may be a la"
# n and dragon in his cave--it
# may be a latter
# therepelve
# maving and derew apthece to profengestonger "sman, accust, the concernion of
# blook refoy
# heay, the proborous permently, friedmby onlfrengt-fonever deppessially, most--2wecking in
# reslentance enous longrow regadea!,"--that regomsestinge" and-constitation of
# man susanntetiees as he dreating, vent,--sub9le," knowledge:
# in loodigation of easly, and namalately manb!orod aboption. as the
# 200285/200285 [==============================] - 140s 700us/sample - loss: 1.6142
# Epoch 3/4
#  - ETA: 7s - loss: 1.5272
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocration of the moral and perhaps that it is a sense that it is a sense of the pather of the sense of the moral that the more of the sense that it is the pather in the sense of the power the sense of a more of the moral to the partical their conscience of the more that the moral of the most did and delight of the sense in the destraint of the present and an action of the moral and the sense of the par
# ----- diversity: 0.5
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocrations. the most because and spiritual, the best burded the canger, in the procher and himself but and sense to a perhaps to phend, and therefore who and speak and bad and develops him                                                                                for it the science in the destraicture of respectary from its self-and a could so ever expressive in the most precised entire and intermi
# ----- diversity: 1.0
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocratingsh other" and more creas?"
# in ideal."
#
# kindike resideres adzict, who are appear approed (their causts wrusudian?" it must deferest to behed beound looks middentarily nay the
# exalnce in pleasure is myn"which willnger amitely event cildical psy wholing, is that heave, and men of fund of very
# hant nesseriss didend to the
# .there. to the knew great to did to its else have once the herrol in spiritl
# ----- diversity: 1.2
# ----- Generating with seed: "s hitherto been the work of an
# aristocra"
# s hitherto been the work of an
# aristocrations,
# hitherto offeasured.
# hev mentarbaless
# bud tewdabley for ipmors
# to lom, strenger which beincted not policgphudful menting--in whome do not deed! a etictr:
# dimstinct and she; kor." a cultured rarely hithertial gre instoncencted man imsequect (on loves
# deted itientable, but fund thought
# nowarsval nlithes changliserive
# wime of it--perhaps fluire?
# it is vilwnou, uppectionual
# 'n-tencifical adules
# 200285/200285 [==============================] - 137s 682us/sample - loss: 1.5300
# Epoch 4/4
#  - ETA: 48s - loss: 1.4807
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless and the strength of the prosirity of the streasure his own strength of the same and his own condition of the problem of the prosirion in the strength of the streasure of the strength of the morality and origin of the same to the sense of the still and all the striven and have and all the strength and so in the word and in the strength of the soul and world of the strength and with such a standar
# ----- diversity: 0.5
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless as the philosophers and self-deness and and have be
# instinct and an artistic life to the profound in the pression of its artal, it was the result in the condition. he who himself conscience and so we he say and an exciple, and in no man when they afferreally be consciousness of the sense of
# truesty and to to be together may and his own self-morality that the
# inflicted, so the words of the morali
# ----- diversity: 1.0
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unless. herd and operation all  nespead by
# educated they, we contrads wad which en eersial canters from whyn underitaness "mostofients aim menlink, assestoments; and effects,
#  , man in which part
# own dender in the wine
# this wishes.
#
# a
# d belong hooved most betre changety of the rewine, has love as we make time may in how peaces, into knough themevert for himself by transte still, cless taken in ramity.
# ----- diversity: 1.2
# ----- Generating with seed: "the herd") has hitherto triumphed. unles"
# the herd") has hitherto triumphed. unlessful will pleiciin of
# rescretar. together be dyil of a constantly as arcsn eiribermings afts a of strong,
# hly attentions: that we alwage does nequence of this .--hitherto
#  ?
#
#
#
#
#
# yt has at atterminges, althiegly right and
# : to the
# congraon for him wished, hought stands,os!
#
#  spiratien tente do nature of way.--a contrans in goes ye pleass franme, per"and
# one, only art we lapkafness--has his, egoib
# 200285/200285 [==============================] - 136s 677us/sample - loss: 1.4839

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires <b>h5py packages</b>, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear200.h5')


def lstm_generate(seed, model):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the subjections of the subjection of the subjection of the sense of the subjection of the such a particularly the subjection of the subjection of the subjection of the sense of the present the passes of the subjection of the sense of the so the subjection of the more to the subjection of all the like the present to the subjection of the states the subjection of the subjection of the subjection of t
# ----- diversity: 0.5
# ----- Generating with seed: "of the subjection of the subjection of t"
# of the subjection of the subjection of the even about that the subjection of it the community when he was the subjection of the to so far about the seen there is a mustic come the like the confiding and the
# children--and such the more the particularly, what is to the probably the forces of the so far of such the present and the sense to the nature. the ends only a propaciates of merely the present in the
# present in the so called and the
# ----- diversity: 1.0
# ----- Generating with seed: " in the
# present in the so called and the"
#  in the
# present in the so called and the mas nolled fehision chance to these develops
# have it is the worldest tencein and song the devinced.itimingloging with a pheasies. it is hear or. the like
# i affidial demangrous to aby naturance, is to germans the passe,
# with this learly men to aleary called carefully out or wat like with rapar in the newly upon the charminess, and because the way, thste and abuteded a can of
# prequest pro"sons of p
# ----- diversity: 1.2
# ----- Generating with seed: "abuteded a can of
# prequest pro"sons of p"
# abuteded a can of
# prequest pro"sons of pposeth, is bagual nouled,"s, this he offerms of world, that the crefinisyric.
# still matestlined to
# have properrom of man, theregoxiest with the
# rathersicred to every pathe exherasidificure--as nobil impulsed stepshting, a
# bloves of arbinarly all
# which would be anverohy of this catementouse"--whan is
# terpomsble man, amrears it to power--as to love
# might nair, greatest owring
# than this
# of great alon
# Using TensorFlow backend.

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The baby name data set contains 8000 names. You can download and process the name data set as follows:
#
# ``` python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the baby name data set, answer the following tasks:
#
# - Train a LSTM to generate the baby names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?

# %%
#need future import print function?
import tensorflow as tf
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io

name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
with io.open(name_path, encoding='utf-8') as f:
    raw_text = f.read() # make it all lowercase

split_text = raw_text.split()
joined_text = ', '.join(split_text)

text= joined_text # for on_epoch_end

# %%
def vectorize_data_into_x_and_y(text):
    chars = sorted(list(set(text)))
    print('total chars:', len(chars))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    
    
    maxlen = 25
    step = 2
    sentences = []
    next_chars = []
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
    print('nb sequences:', len(sentences))
    
    # Turn these sentances into one-hot encoded vectors
    ## For all words in the sentances, there is a one, else there is a zero in that index of the vector
    
    print('Vectorization...')
    x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
    print('Done!')
    
    return x, y, maxlen, chars, char_indices, indices_char

x, y, maxlen, chars, char_indices, indices_char = vectorize_data_into_x_and_y(joined_text)
# Out:
# total chars: 58
# nb sequences: 250882
# Vectorization...
# Done!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')




print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
# Out:
# Build model...
# Done!

# %%
model.fit(x, y,
          batch_size=128,
          epochs=8,
          callbacks=[print_callback],
          use_multiprocessing=True,
          workers=16)
# Out:
# Train on 250882 samples
# Epoch 1/8
#  - ETA: 1:00 - loss: 1.9891
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ange, Pranger, Prasad, Pr"
# ange, Pranger, Prasad, Prasch, Prascher, Prase, Prasen, Prasell, Prasell, Prasell, Praser, Prasser, Praster, Praster, Praster, Praster, Prastin, Prastin, Prastin, Prastin, Prast, Praster, Praster, Praster, Praster, Praster, Prastin, Prastin, Prastin, Prastin, Prastin, Prastin, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt,
# ----- diversity: 0.5
# ----- Generating with seed: "ange, Pranger, Prasad, Pr"
# ange, Pranger, Prasad, Prase, Prase, Praser, Prassin, Prassell, Prassell, Praster, Prastell, Prastin, Pratt, Pratt, Pratter, Prattin, Prattin, Pratt, Pratt, Pratte, Pratter, Pratter, Pratt, Pratte, Pratter, Pratt, Pratter, Pratt, Prattin, Pratt, Prattr, Pratte, Pratt, Pratte, Pratt, Pratter, Prattin, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Pratt, Prattel, Pratt, Pratt, Pratt, Pratter, Prattin, Prattin, Prattin, P
# ----- diversity: 1.0
# ----- Generating with seed: "ange, Pranger, Prasad, Pr"
# ange, Pranger, Prasad, Pransca, Pranswolt, Pran, Prandol, Prane, Prandeo, Prandy, Pran, Plane, Pranitro, Pranith, Prank, Pranilla, Pranner, Pranrill, Pranwort, Pranty, Prantan, Prantin, Planstento, Plasternde, Playstood, Plast, Plar, Plargad, Plar, Plarelli, Plarere, Plarer, Plaress, Plarit, Plare, Plarker, Plarn, Plaroza, Plass, Plasski, Platz, Plazz, Plagas, Plah, Plaie, Plaie, Plaine, Plalick, Plalio, Plapk, Plaliti, P
# ----- diversity: 1.2
# ----- Generating with seed: "ange, Pranger, Prasad, Pr"
# ange, Pranger, Prasad, Pranett, Pranfsan, Prano, Prany, Praver, Prablott, Prabro, Prbreb, Pretney, Prelte, Greltvabe, Pres, Prembe, Predma, Predon, Predy, Predeo, Predell, Pred, Preckes, Predontoll, Preder, Predetin, Predki, Prefer, Pretd, Prett, Prenting, Preuchale, Pretia, Pretins, Pretrier, Prethman, Prettridah, Pretz, Prevel, Preves, Preht, Preisel, Preist, Prein, Priebe, Preip, Prien, Priph, Prip, Propt, Prophe, Proq
# 250882/250882 [==============================] - 118s 470us/sample - loss: 1.2668
# Epoch 2/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.8792
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "y, Raya, Raybon, Rayborn,"
# y, Raya, Raybon, Rayborn, Raybert, Raybert, Raybert, Raybert, Rayben, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Rayb
# ----- diversity: 0.5
# ----- Generating with seed: "y, Raya, Raybon, Rayborn,"
# y, Raya, Raybon, Rayborn, Raybert, Raybes, Raybert, Raybord, Rayberg, Raybert, Raybert, Rayberg, Raybert, Raybert, Raybert, Raybert, Raybert, Raybett, Raybert, Raybill, Rayble, Rayble, Raybert, Raybert, Raybert, Rayan, Rayber, Raybert, Raybert, Raybert, Rayble, Raybert, Raybert, Raybert, Raybert, Raybert, Raybert, Raybin, Rayberg, Raybert, Raybert, Raybert, Raybert, Raybert, Raybel, Rayben, Raybert, Raybert, Raybers, Rayb
# ----- diversity: 1.0
# ----- Generating with seed: "y, Raya, Raybon, Rayborn,"
# ----- diversity: 0.5
# ----- Generating with seed: "l, Mcmichen, Mcmickle, Mc"
# l, Mcmichen, Mcmickle, Mcmidke, Mcmidley, Mcmidelli, Mcmidelli, Mcmidette, Mcmido, Mcmidine, Mcmidiene, Mcmidielli, Mcmidine, Mcmidiota, Mcmidite, Mcmidine, Mcmidine, Mcmidiele, Mcmidelli, Mcmidette, Mcmidis, Mcmidio, Mcmidton, Mcmidthin, Mcmidrett, Mcmidley, Mcmidler, Mcmidle, Mcmidel, Mcmidelli, Mcmidella, Mcmidoli, Mcmidelli, Mcmidian, Mcmidiello, Mcmidine, Mcmidin, Mcmidia, Mcmidie, Mcmidian, Mcmidelli, Mcmidillo, Mcm
# ----- diversity: 1.0
# ----- Generating with seed: "l, Mcmichen, Mcmickle, Mc"
# l, Mcmichen, Mcmickle, Mcmick, Mcmide, Mcmidelle, Mcmidinli, Mcmidinel, Mcmiheley, Mcmingsen, Mcmmirs, Mcmminson, Mcmminstein, Mcmmont, Mcmmonn, Mcmmonson, Mcmmont, Mcmmondon, Mcmmonson, Mcmmonstr, Mcmoncki, Mcmmone, Mcmmones, Mcmmonstedle, Mcmmonty, Mcmonkey, Mcmonkite, Mcmor, Mcmordaker, Mcmorralt, Mcmorryton, Mcmorotte, Mcmorstream, Mcmorryn, Mcmorry, Mcmorkey, Mcmorer, Mcmorey, Mcmorlyn, Mcmortin, Mcmoreste, Mcmorutto
# ----- diversity: 1.2
# ----- Generating with seed: "l, Mcmichen, Mcmickle, Mc"
# l, Mcmichen, Mcmickle, Mcmicken, Mcmidy, Mcmmian, Mcmmman, Mcmmon, Mcmmone, Mcmmone, Mcmmonski, Mcmmons, Mcmmons, Mcmmro, Mcmorr, Mcmotpridget, Mcmoughstlr, Mcmughan, Mcmuinny, Mcmidtiani, Mcmuigst, Mcminelli, Mcmmill, Mcmmmighen, Mcmmolow, Mcmmron, Mcmorwitt, Mcmorsten, Mcmorsy, Mccotlato, Mckucelter, Mctideto, Mcididle, Mckidra, Mckidwande, Mckewski, Mcke, Mckein, Mcjahlin, Mukey, Mukarro, Mukel, Mukuelki, Muksitt, Muks
# 250882/250882 [==============================] - 109s 434us/sample - loss: 0.7493
# Epoch 7/8
# 250752/250882 [============================>.] - ETA: 0s - loss: 0.7362
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "k, Hitchens, Hitchings, H"
# k, Hitchens, Hitchings, Hitchinst, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching, Hitching,
# ----- diversity: 0.5
# ----- Generating with seed: "k, Hitchens, Hitchings, H"
# k, Hitchens, Hitchings, Hitchman, Hitchrick, Hitchenbaugh, Hitchermeyer, Hidter, Hidt, Hidwina, Hidyer, Hiezman, Hiezan, Hiezer, Hiezel, Hiezberg, Hiezberg, Hiezmer, Hiezke, Hiewan, Hiezen, Hiezen, Hiezen, Hiezbing, Hiezina, Hiezber, Hiezber, Hiezber, Hiezler, Hiezber, Hiezel, Hiezer, Hiezberg, Hiezen, Hiezer, Hiezber, Hiezber, Hiezbert, Hiezber, Hiezen, Hiezer, Hiezman, Hieze, Hiezer, Hiezer, Hiezhe, Hiezer, Hiezinski, H
# ----- diversity: 1.0
# ----- Generating with seed: "k, Hitchens, Hitchings, H"
# k, Hitchens, Hitchings, Hitey, Hitener, Hiting, Hitko, Hitkne, Hitkhey, Hitkinski, Hitkowski, Hitning, Hitrise, Hitrose, Hitroom, Hitring, Hitsiok, Hitson, Hitz, Hitzmayer, Hitzee, Hitzengam, Hiu, Hiaubich, Hiau, Hianzka, Hiak, Hiara, Hian, Hianoff, Hiantz, Hiasseck, Hiath, Hiath, Hiatand, Hibauls, Hibbman, Hibbing, Hibbins, Hibbsen, Hibbield, Hibbing, Hibbins, Hibbs, Hibbers, Hibbkaway, Hibbelker, Hibblemith, Hibbley, Hi
# ----- diversity: 1.2
# ----- Generating with seed: "k, Hitchens, Hitchings, H"
# k, Hitchens, Hitchings, Hithard, Hither, Hithaway, Hitick, Dithie, Ditlead, Ditter, Ditzing, Di, Dida, Dide, Didel, Dideman, Didem, Didem, Dideri, Didetago, Dididori, Didiola, Didito, Didke, Dig, Digen, Digen, Digenay, Digglauldre, Diggsen, Diggman, Diggnart, Diggy, Digin, Digik, Digermaier, Digg, Diggers, Digersky, Digin, Digo, Digulo, Diguiaelki, Digortzi, Digwoode, Diguoeo, Digwood, Digu, Digut, Dignumoto, Digrus, Digo
# 250882/250882 [==============================] - 113s 452us/sample - loss: 0.7363
# Epoch 8/8
# 250880/250882 [============================>.] - ETA: 0s - loss: 0.7232
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "Trout, Troutman, Troutner"
# Trout, Troutman, Troutner, Troutner, Trouth, Trouth, Trouth, Trouth, Trouther, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouther, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Troutsch, Troutsell, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouther, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouth, Trouther, Trouth,
# ----- diversity: 0.5
# ----- Generating with seed: "Trout, Troutman, Troutner"
# Trout, Troutman, Troutner, Trouth, Trouth, Trouth, Trouth, Troutherly, Trover, Trovers, Troverson, Trover, Trovers, Trovers, Troskey, Troson, Trospers, Trospin, Trospert, Trosperry, Trospers, Tross, Trossell, Trosser, Trossi, Trossins, Trossinger, Trosh, Trosher, Trosher, Troshell, Trosher, Troshen, Troshen, Troshim, Troskin, Trosley, Tross, Trossell, Trossie, Trossell, Trossie, Trost, Trostinger, Trother, Trothers, Troth
# ----- diversity: 1.0
# ----- Generating with seed: "Trout, Troutman, Troutner"
# Trout, Troutman, Troutner, Trouver, Trover, Trovemp, Troves, Troveth, Trowchard, Trowdolm, Trowell, Trowsck, Troubert, Troudern, Trouchler, Troudenberg, Troudew, Trouell, Trounborn, Trooy, Tropans, Troppel, Tropper, Troptins, Tror, Tros, Trosing, Trosip, Troskel, Trosley, Trosak, Troski, Trosl, Trosnik, Trosi, Trosh, Trosher, Troshenson, Trosienski, Trosner, Trosotal, Trosta, Trotco, Trotteir, Trotton, Trother, Troteri, T
# ----- diversity: 1.2
# ----- Generating with seed: "Trout, Troutman, Troutner"
# Trout, Troutman, Troutnerino, Trouphry, Trotuzyn, Trotzek, Trouis, Trouif, Troul, Troulis, Trouls, Troulin, Trouland, Trulploy, Trullbach, Truelibe, Trules, Truldiwshide, Truheali, Truier, Truhitro, Truin, Trutolollo, Truiesor, Truie, Truiff, Truig, Truilen, Trull, Trum, Trumlia, Trummuch, Trumpson, Trums, Trumley, Trumney, Trumombock, Trumith, Trumelynner, Trundertz, Trunders, Trune, Trunne, Trup, Trupp, Trusen, Truso, T
# 250882/250882 [==============================] - 112s 446us/sample - loss: 0.7232

# %% [markdown]
# Training the baby-name-generator took 895 seconds for 8 epochs, around 112 seconds per epoch.
# I'm not sure if it became more coherent/realistic over this stretch of training beacuse most of the baby names in the training data sound so strange to me that I'm not confident about judging how different one of the network's generated names is from the given dataset of baby names.

# %%
from keras.utils import Sequence

class ShufflePerEpochSequence(Sequence):
    def __init__(self, split_text, batch_size):
        self.split_text = split_text
        self.batch_size = batch_size
        self.text = ', '.join(self.split_text)
        x, y, maxlen, chars, char_indices, indices_char = vectorize_data_into_x_and_y(self.text)
        self.x = x
        self.y = y
        

    def __len__(self):
        return int(np.ceil( len(self.x) / float(self.batch_size) ))


    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        return np.array(batch_x), np.array(batch_y)


    #todo copy in vectorize_data... function?

    def on_epoch_end(self):
        shuffled_split_text = random.shuffle(self.split_text)
        self.text = ', '.join(shuffled_split_text)
        x, y, maxlen, chars, char_indices, indices_char = vectorize_data_into_x_and_y(self.text)
        self.x = x
        self.y = y
        
        print()
        print('----- Generating text after Epoch: %d' % epoch)
    
        start_index = random.randint(0, len(self.text) - maxlen - 1)
        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print('----- diversity:', diversity)
    
            generated = ''
            sentence = self.text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)
    
            for i in range(400):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.
    
                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]
    
                generated += next_char
                sentence = sentence[1:] + next_char
    
                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# Using TensorFlow backend.

# %%
shufflingDataSequence = ShufflePerEpochSequence(split_text, 128)
print(shufflingDataSequence)
model.fit_generator(shufflingDataSequence, epochs=8,
          use_multiprocessing=True,
          workers=16)
# Out:
# total chars: 58
# nb sequences: 250882
# Vectorization...
# Done!
# <__main__.ShufflePerEpochSequence object at 0x000002AF5E1B0308>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-eb7bea6e246c> in <module>
#       3 model.fit_generator(shufflingDataSequence, epochs=8,
#       4           use_multiprocessing=True,
# ----> 5           workers=16)
#       6
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1304         use_multiprocessing=use_multiprocessing,
#    1305         shuffle=shuffle,
# -> 1306         initial_epoch=initial_epoch)
#    1307
#    1308   @deprecation.deprecated(
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     233           max_queue_size=max_queue_size,
#     234           workers=workers,
# --> 235           use_multiprocessing=use_multiprocessing)
#     236
#     237       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     531                      'at same time.')
#     532
# --> 533   adapter_cls = data_adapter.select_data_adapter(x, y)
#     534
#     535   # Handle validation_split, we want to split the data and get the training
#
# c:\users\ssili\pycharmprojects\cis3715-temple-2020.github.io\venv\lib\site-packages\tensorflow_core\python\keras\engine\data_adapter.py in select_data_adapter(x, y)
#     996         "Failed to find data adapter that can handle "
#     997         "input: {}, {}".format(
# --> 998             _type_name(x), _type_name(y)))
#     999   elif len(adapter_cls) > 1:
#    1000     raise RuntimeError(
#
# ValueError: Failed to find data adapter that can handle input: <class '__main__.ShufflePerEpochSequence'>, <class 'NoneType'>
